# %%
from bs4 import BeautifulSoup   
from selenium import webdriver

option = webdriver.ChromeOptions()
option.add_argument("--incognito")

# driver.get("https://www.ptt.cc/bbs/MakeUp/index.html")
# soup = BeautifulSoup(driver.page_source ,"html.parser") 


driver = webdriver.Chrome("D:/chromedriver_win32/chromedriver.exe", chrome_options=option)
driver.get('https://www.ptt.cc/bbs/MakeUp/index.html')

# %%
from urllib.parse import urljoin
def parse_page(soup):
    big_tag = soup.find_all(class_ = "r-ent")  #or big_tag = soup.select(".r-ent")    #the whole div
    pre =  soup.find_all(class_ = "btn wide")
    pre_url=pre[1]['href']
    print("pre url is",pre_url)
    complete_pre_url = urljoin(base_url, pre_url)
    results=[]
    i = 0
    while i < len(big_tag):
        num = big_tag[i].find(class_="nrec").next_element.string
        try:
            title = big_tag[i].find('a').string
            textUrl = big_tag[i].find('a','herf')
            complete_textUrl = urljoin(base_url, textUrl)
        except AttributeError:
            title = "本文已刪除"
            complete_textUrl = '此文章的url不存在'
        author = big_tag[i].find(class_='author').string
        date=big_tag[i].find(class_='date').string
        i=i+1
        r = dict(
        num=num,
        title=title,
        author=author,
        date=date)
        results += [r]
        print(num,title,author,date,complete_textUrl)
    return results,complete_pre_url,complete_textUrl,title
rs,url,complete_textUrl,title= parse_page(soup)
# Out:
# pre url is /bbs/MakeUp/index3030.html
#
#  本文已刪除 -  7/01 此文章的url不存在
# 21 [選擇] 尋攜帶方便的粉調底妝 LSY31  7/01 https://www.ptt.cc/bbs/MakeUp/index.html
# 3 本文已刪除 -  7/01 此文章的url不存在
# 44 [問題] 底妝完上蜜粉變得斑駁? pinot  7/01 https://www.ptt.cc/bbs/MakeUp/index.html
# 5 [閒聊] 二手公益彩妝挖寶趣 frbkimo  7/01 https://www.ptt.cc/bbs/MakeUp/index.html
# 34 [心得] CP值爆表開架腮紅 4u2 love me more jammy01234  7/01 https://www.ptt.cc/bbs/MakeUp/index.html
# 26 [問題] 類似的透明感高閃偏光單色眼影 gogogo572052  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
# 44 [公告] 有關YSL限量76平價替代色一文之判決 leon8712  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
# 7 [閒聊] 2018/7月 置底打屁閒聊區 leon8712  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
#
#  [情報] 2018/7月 熱門商品推文區 leon8712  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
#
#  本文已刪除 -  7/02 此文章的url不存在
#
#  [選擇] everyday minerals選色問題 ohliangmai  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
#
#  [公告] 美妝板規 ★ 問與答 2018-6-15重新發表 leon8712  5/15 https://www.ptt.cc/bbs/MakeUp/index.html
# 50 [公告] 新板規發佈後之延伸說明及參考 leon8712  6/01 https://www.ptt.cc/bbs/MakeUp/index.html
# 19 [閒聊] 2018/7月 置底打屁閒聊區 leon8712  7/02 https://www.ptt.cc/bbs/MakeUp/index.html
# 1 [情報] 2018/7月 熱門商品推文區 leon8712  7/02 https://www.ptt.cc/bbs/MakeUp/index.html

# %%
driver.find_element_by_xpath("""//*[@id="action-bar-container"]/div/div[2]/a[2]""").click()  

#use soup to parse the page
soup = BeautifulSoup(driver.page_source ,"html.parser")  
xs = soup.select(".title")
for i in xs:
    print(i.text)
# Out:
# [心得] 帶小孩玩一整天都不脫妝的雅詩粉持久！
#
#
# [妝容] 傳說對決最正女神莉莉安！
#
#
# [心得] 超難買的YSL76&簡短法國代運心得
#
#
# [閒聊] 達不到凹凹任務
#
#
# [心得] Nabla Soul Blooming 使用心得分享
#
#
# [閒聊] 又用凹什麼了兼打亮產品分享
#
#
# [心得] 一再回購的蘭芝最新Stained glasstick
#
#
# [閒聊] 是晃祐堂x拉拉熊 刷具
#
#
# [選擇] 妝前保濕，MAC持妝露還是LM煥顏凝露
#
#
# [心得] 等好久!ofra三色打亮開箱
#
#
#
# 				(本文已被刪除) [GinHouse]
#
#
#
# [公告] 水桶名單
#
#
# [閒聊] YSL限量76平價替代色 & 2018的限量脣彩們
#
#
# [選擇] IKEA打造化妝空間
#
#
# [心得] 極度讚嘆integrate彎彎翹麗睫毛膏
#
#
# [問題] 新手眼妝及眉毛求批
#
#
# [心得] NYX 紫x桃紅 漸層腮紅&紫色偏光打亮分享
#
#
# [心得] essence炫光腮紅vs Jouer打亮 是雙胞胎！
#
#
# [心得] 黑五後新購入的超過35支唇彩試色分享
#
#
# [心得] 蘭蔻氣墊盒可裝Mac粉芯唷！！
